# %% [markdown]
# The data used in this workflow is comes from: Study: COVID-19 lung autopsy samples <br> Found at https://singlecell.broadinstitute.org/single_cell/study/SCP1052/covid-19-lung-autopsy-samples?scpbr=immune-cell-atlas#study-download <br>
# The dataset that was used was lung.h5ad.gz which is h5ad of full lung dataset

# %% [markdown]
# Here I am following the scanpy tutroail for preprocessing and clustering. Found here: https://scanpy-tutorials.readthedocs.io/en/latest/pbmc3k.html

# %%
conda install -c bioconda scanpy
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: |
# Found conflicts! Looking for incompatible packages.
# This can take several minutes.  Press CTRL-C to abort.
#                                                                                failed
#
# UnsatisfiableError: The following specifications were found to be incompatible with each other:
#
# Output in format: Requested package -> Available versions
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install scanpy
# Out:
# Collecting scanpy
#   Using cached scanpy-1.8.2-py3-none-any.whl (2.0 MB)
# Collecting seaborn
#   Downloading seaborn-0.11.2-py3-none-any.whl (292 kB)
#      |████████████████████████████████| 292 kB 2.0 MB/s eta 0:00:01
# Collecting natsort
#   Using cached natsort-8.1.0-py3-none-any.whl (37 kB)
# Requirement already satisfied: pandas>=0.21 in /Users/danielaquijano/opt/anaconda3/envs/NewPython33122/lib/python3.8/site-packages (from scanpy) (1.4.1)
# Collecting umap-learn>=0.3.10
#   Using cached umap_learn-0.5.2-py3-none-any.whl
# Collecting tables
#   Downloading tables-3.7.0-cp38-cp38-macosx_10_9_x86_64.whl (5.9 MB)
#      |████████████████████████████████| 5.9 MB 5.3 MB/s eta 0:00:01     |██████████████████████▏         | 4.1 MB 3.1 MB/s eta 0:00:01
# Collecting h5py>=2.10.0
#   Downloading h5py-3.6.0-cp38-cp38-macosx_10_9_x86_64.whl (3.1 MB)
#      |████████████████████████████████| 3.1 MB 6.1 MB/s eta 0:00:01
# Collecting networkx>=2.3
#   Downloading networkx-2.7.1-py3-none-any.whl (2.0 MB)
#      |████████████████████████████████| 2.0 MB 3.1 MB/s eta 0:00:01
# Collecting scipy>=1.4
#   Using cached scipy-1.8.0-cp38-cp38-macosx_12_0_universal2.macosx_10_9_x86_64.whl (55.3 MB)
# Collecting patsy
#   Downloading patsy-0.5.2-py2.py3-none-any.whl (233 kB)
#      |████████████████████████████████| 233 kB 2.1 MB/s eta 0:00:01
# Collecting scikit-learn>=0.22
#   Using cached scikit_learn-1.0.2-cp38-cp38-macosx_10_13_x86_64.whl (7.9 MB)
# Collecting tqdm
#   Downloading tqdm-4.63.1-py2.py3-none-any.whl (76 kB)
#      |████████████████████████████████| 76 kB 1.7 MB/s eta 0:00:01
# Collecting anndata>=0.7.4
#   Using cached anndata-0.8.0-py3-none-any.whl (96 kB)
# Collecting numba>=0.41.0
#   Downloading numba-0.55.1.tar.gz (2.3 MB)
#      |████████████████████████████████| 2.3 MB 3.7 MB/s eta 0:00:01
# Collecting statsmodels>=0.10.0rc2
#   Downloading statsmodels-0.13.2-cp38-cp38-macosx_10_9_x86_64.whl (9.6 MB)
#      |████████████████████████████████| 9.6 MB 3.8 MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.17.0 in /Users/danielaquijano/opt/anaconda3/envs/NewPython33122/lib/python3.8/site-packages (from scanpy) (1.21.2)
# Collecting joblib
#   Downloading joblib-1.1.0-py2.py3-none-any.whl (306 kB)
#      |████████████████████████████████| 306 kB 2.9 MB/s eta 0:00:01
# Collecting matplotlib>=3.1.2
#   Using cached matplotlib-3.5.1-cp38-cp38-macosx_10_9_x86_64.whl (7.3 MB)
# Requirement already satisfied: packaging in /Users/danielaquijano/opt/anaconda3/envs/NewPython33122/lib/python3.8/site-packages (from scanpy) (21.3)
# Collecting sinfo
#   Using cached sinfo-0.3.4-py3-none-any.whl
# Collecting pillow>=6.2.0
#   Downloading Pillow-9.0.1-cp38-cp38-macosx_10_10_x86_64.whl (3.0 MB)
#      |████████████████████████████████| 3.0 MB 5.1 MB/s eta 0:00:01
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.4.2-cp38-cp38-macosx_10_9_x86_64.whl (65 kB)
#      |████████████████████████████████| 65 kB 3.8 MB/s eta 0:00:01
# Requirement already satisfied: python-dateutil>=2.7 in /Users/danielaquijano/opt/anaconda3/envs/NewPython33122/lib/python3.8/site-packages (from matplotlib>=3.1.2->scanpy) (2.8.2)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.31.2-py3-none-any.whl (899 kB)
#      |████████████████████████████████| 899 kB 5.4 MB/s eta 0:00:01
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/danielaquijano/opt/anaconda3/envs/NewPython33122/lib/python3.8/site-packages (from matplotlib>=3.1.2->scanpy) (3.0.4)
# Collecting cycler>=0.10
#   Downloading cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Collecting llvmlite<0.39,>=0.38.0rc1
#   Downloading llvmlite-0.38.0-cp38-cp38-macosx_10_9_x86_64.whl (25.5 MB)
#      |████████████████████████████████| 25.5 MB 5.5 MB/s eta 0:00:01     |████████████████████▎           | 16.2 MB 4.7 MB/s eta 0:00:02
# Requirement already satisfied: setuptools in /Users/danielaquijano/opt/anaconda3/envs/NewPython33122/lib/python3.8/site-packages (from numba>=0.41.0->scanpy) (58.0.4)
# Requirement already satisfied: pytz>=2020.1 in /Users/danielaquijano/opt/anaconda3/envs/NewPython33122/lib/python3.8/site-packages (from pandas>=0.21->scanpy) (2021.3)
# Requirement already satisfied: six>=1.5 in /Users/danielaquijano/opt/anaconda3/envs/NewPython33122/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib>=3.1.2->scanpy) (1.16.0)
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
# Collecting pynndescent>=0.5
#   Using cached pynndescent-0.5.6-py3-none-any.whl
# Collecting stdlib-list
#   Using cached stdlib_list-0.8.0-py3-none-any.whl (63 kB)
# Requirement already satisfied: numexpr>=2.6.2 in /Users/danielaquijano/opt/anaconda3/envs/NewPython33122/lib/python3.8/site-packages (from tables->scanpy) (2.8.1)
# Building wheels for collected packages: numba
#   Building wheel for numba (setup.py) ... error
#   ERROR: Command errored out with exit status 1:
#    command: /Users/danielaquijano/opt/anaconda3/envs/NewPython33122/bin/python -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/kz/671nytjx6wbb6qvvfpv7jwt00000gn/T/pip-install-zdjyhqrq/numba_f105f788a65940c9b7a7207648255752/setup.py'"'"'; __file__='"'"'/private/var/folders/kz/671nytjx6wbb6qvvfpv7jwt00000gn/T/pip-install-zdjyhqrq/numba_f105f788a65940c9b7a7207648255752/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d /private/var/folders/kz/671nytjx6wbb6qvvfpv7jwt00000gn/T/pip-wheel-veg0sl47
#        cwd: /private/var/folders/kz/671nytjx6wbb6qvvfpv7jwt00000gn/T/pip-install-zdjyhqrq/numba_f105f788a65940c9b7a7207648255752/
#   Complete output (831 lines):
#   TBB not found
#   Using OpenMP from: /Users/danielaquijano/opt/anaconda3
#   running bdist_wheel
#   running build
#   got version from file /private/var/folders/kz/671nytjx6wbb6qvvfpv7jwt00000gn/T/pip-install-zdjyhqrq/numba_f105f788a65940c9b7a7207648255752/numba/_version.py {'version': '0.55.1', 'full': '76720bf88350c70b99ab3d4272d01bd9f14eeace'}
#   running build_py
#   creating build
#   creating build/lib.macosx-10.9-x86_64-3.8
#   creating build/lib.macosx-10.9-x86_64-3.8/numba
#   copying numba/_version.py -> build/lib.macosx-10.9-x86_64-3.8/numba
#   copying numba/__init__.py -> build/lib.macosx-10.9-x86_64-3.8/numba
#   copying numba/__main__.py -> build/lib.macosx-10.9-x86_64-3.8/numba
#   copying numba/runtests.py -> build/lib.macosx-10.9-x86_64-3.8/numba
#   copying numba/extending.py -> build/lib.macosx-10.9-x86_64-3.8/numba
#   creating build/lib.macosx-10.9-x86_64-3.8/numba/misc
#   copying numba/misc/literal.py -> build/lib.macosx-10.9-x86_64-3.8/numba/misc
#   copying numba/misc/quicksort.py -> build/lib.macosx-10.9-x86_64-3.8/numba/misc
#   copying numba/misc/numba_entry.py -> build/lib.macosx-10.9-x86_64-3.8/numba/misc
#   copying numba/misc/__init__.py -> build/lib.macosx-10.9-x86_64-3.8/numba/misc
#   copying numba/misc/inspection.py -> build/lib.macosx-10.9-x86_64-3.8/numba/misc
#   copying numba/misc/cffiimpl.py -> build/lib.macosx-10.9-x86_64-3.8/numba/misc
#   copying numba/misc/appdirs.py -> build/lib.macosx-10.9-x86_64-3.8/numba/misc
#   copying numba/misc/init_utils.py -> build/lib.macosx-10.9-x86_64-3.8/numba/misc
#   copying numba/misc/findlib.py -> build/lib.macosx-10.9-x86_64-3.8/numba/misc
#   copying numba/misc/numba_sysinfo.py -> build/lib.macosx-10.9-x86_64-3.8/numba/misc
#   copying numba/misc/gdb_hook.py -> build/lib.macosx-10.9-x86_64-3.8/numba/misc
#   copying numba/misc/dummyarray.py -> build/lib.macosx-10.9-x86_64-3.8/numba/misc
#   copying numba/misc/llvm_pass_timings.py -> build/lib.macosx-10.9-x86_64-3.8/numba/misc
#   copying numba/misc/mergesort.py -> build/lib.macosx-10.9-x86_64-3.8/numba/misc
#   copying numba/misc/timsort.py -> build/lib.macosx-10.9-x86_64-3.8/numba/misc
#   copying numba/misc/special.py -> build/lib.macosx-10.9-x86_64-3.8/numba/misc
#   copying numba/misc/dump_style.py -> build/lib.macosx-10.9-x86_64-3.8/numba/misc
#   creating build/lib.macosx-10.9-x86_64-3.8/numba/experimental
#   copying numba/experimental/function_type.py -> build/lib.macosx-10.9-x86_64-3.8/numba/experimental
#   copying numba/experimental/structref.py -> build/lib.macosx-10.9-x86_64-3.8/numba/experimental
#   copying numba/experimental/__init__.py -> build/lib.macosx-10.9-x86_64-3.8/numba/experimental
#   creating build/lib.macosx-10.9-x86_64-3.8/numba/types
#   copying numba/types/__init__.py -> build/lib.macosx-10.9-x86_64-3.8/numba/types
#   creating build/lib.macosx-10.9-x86_64-3.8/numba/core
#   copying numba/core/fastmathpass.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core
#   copying numba/core/dispatcher.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core
#   copying numba/core/serialize.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core
#   copying numba/core/funcdesc.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core
#   copying numba/core/postproc.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core
#   copying numba/core/options.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core
#   copying numba/core/transforms.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core
#   copying numba/core/compiler_machinery.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core
#   copying numba/core/tracing.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core
#   copying numba/core/event.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core
#   copying numba/core/overload_glue.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core
#   copying numba/core/optional.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core
#   copying numba/core/ccallback.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core
#   copying numba/core/config.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core
#   copying numba/core/compiler.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core
#   copying numba/core/withcontexts.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core
#   copying numba/core/analysis.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core
#   copying numba/core/inline_closurecall.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core
#   copying numba/core/ir_utils.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core
#   copying numba/core/retarget.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core
#   copying numba/core/registry.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core
#   copying numba/core/imputils.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core
#   copying numba/core/pylowering.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core
#   copying numba/core/externals.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core
#   copying numba/core/cpu.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core
#   copying numba/core/lowering.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core
#   copying numba/core/callconv.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core
#   copying numba/core/object_mode_passes.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core
#   copying numba/core/sigutils.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core
#   copying numba/core/__init__.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core
#   copying numba/core/ssa.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core
#   copying numba/core/ir.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core
#   copying numba/core/itanium_mangler.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core
#   copying numba/core/removerefctpass.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core
#   copying numba/core/boxing.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core
#   copying numba/core/consts.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core
#   copying numba/core/intrinsics.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core
#   copying numba/core/generators.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core
#   copying numba/core/descriptors.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core
#   copying numba/core/targetconfig.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core
#   copying numba/core/interpreter.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core
#   copying numba/core/caching.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core
#   copying numba/core/utils.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core
#   copying numba/core/debuginfo.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core
#   copying numba/core/cpu_options.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core
#   copying numba/core/entrypoints.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core
#   copying numba/core/typeinfer.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core
#   copying numba/core/environment.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core
#   copying numba/core/errors.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core
#   copying numba/core/typed_passes.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core
#   copying numba/core/bytecode.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core
#   copying numba/core/byteflow.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core
#   copying numba/core/untyped_passes.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core
#   copying numba/core/dataflow.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core
#   copying numba/core/callwrapper.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core
#   copying numba/core/codegen.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core
#   copying numba/core/target_extension.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core
#   copying numba/core/controlflow.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core
#   copying numba/core/base.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core
#   copying numba/core/cgutils.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core
#   copying numba/core/pythonapi.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core
#   copying numba/core/extending.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core
#   copying numba/core/compiler_lock.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core
#   copying numba/core/decorators.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core
#   creating build/lib.macosx-10.9-x86_64-3.8/numba/cloudpickle
#   copying numba/cloudpickle/cloudpickle.py -> build/lib.macosx-10.9-x86_64-3.8/numba/cloudpickle
#   copying numba/cloudpickle/compat.py -> build/lib.macosx-10.9-x86_64-3.8/numba/cloudpickle
#   copying numba/cloudpickle/__init__.py -> build/lib.macosx-10.9-x86_64-3.8/numba/cloudpickle
#   copying numba/cloudpickle/cloudpickle_fast.py -> build/lib.macosx-10.9-x86_64-3.8/numba/cloudpickle
#   creating build/lib.macosx-10.9-x86_64-3.8/numba/cuda
#   copying numba/cuda/dispatcher.py -> build/lib.macosx-10.9-x86_64-3.8/numba/cuda
#   copying numba/cuda/descriptor.py -> build/lib.macosx-10.9-x86_64-3.8/numba/cuda
#   copying numba/cuda/printimpl.py -> build/lib.macosx-10.9-x86_64-3.8/numba/cuda
#   copying numba/cuda/libdevice.py -> build/lib.macosx-10.9-x86_64-3.8/numba/cuda
#   copying numba/cuda/device_init.py -> build/lib.macosx-10.9-x86_64-3.8/numba/cuda
#   copying numba/cuda/compiler.py -> build/lib.macosx-10.9-x86_64-3.8/numba/cuda
#   copying numba/cuda/models.py -> build/lib.macosx-10.9-x86_64-3.8/numba/cuda
#   copying numba/cuda/intrinsic_wrapper.py -> build/lib.macosx-10.9-x86_64-3.8/numba/cuda
#   copying numba/cuda/mathimpl.py -> build/lib.macosx-10.9-x86_64-3.8/numba/cuda
#   copying numba/cuda/initialize.py -> build/lib.macosx-10.9-x86_64-3.8/numba/cuda
#   copying numba/cuda/cuda_paths.py -> build/lib.macosx-10.9-x86_64-3.8/numba/cuda
#   copying numba/cuda/libdevicefuncs.py -> build/lib.macosx-10.9-x86_64-3.8/numba/cuda
#   copying numba/cuda/simulator_init.py -> build/lib.macosx-10.9-x86_64-3.8/numba/cuda
#   copying numba/cuda/__init__.py -> build/lib.macosx-10.9-x86_64-3.8/numba/cuda
#   copying numba/cuda/types.py -> build/lib.macosx-10.9-x86_64-3.8/numba/cuda
#   copying numba/cuda/random.py -> build/lib.macosx-10.9-x86_64-3.8/numba/cuda
#   copying numba/cuda/api.py -> build/lib.macosx-10.9-x86_64-3.8/numba/cuda
#   copying numba/cuda/stubs.py -> build/lib.macosx-10.9-x86_64-3.8/numba/cuda
#   copying numba/cuda/vectorizers.py -> build/lib.macosx-10.9-x86_64-3.8/numba/cuda
#   copying numba/cuda/args.py -> build/lib.macosx-10.9-x86_64-3.8/numba/cuda
#   copying numba/cuda/target.py -> build/lib.macosx-10.9-x86_64-3.8/numba/cuda
#   copying numba/cuda/cudamath.py -> build/lib.macosx-10.9-x86_64-3.8/numba/cuda
#   copying numba/cuda/libdeviceimpl.py -> build/lib.macosx-10.9-x86_64-3.8/numba/cuda
#   copying numba/cuda/errors.py -> build/lib.macosx-10.9-x86_64-3.8/numba/cuda
#   copying numba/cuda/cudaimpl.py -> build/lib.macosx-10.9-x86_64-3.8/numba/cuda
#   copying numba/cuda/nvvmutils.py -> build/lib.macosx-10.9-x86_64-3.8/numba/cuda
#   copying numba/cuda/testing.py -> build/lib.macosx-10.9-x86_64-3.8/numba/cuda
#   copying numba/cuda/cudadecl.py -> build/lib.macosx-10.9-x86_64-3.8/numba/cuda
#   copying numba/cuda/codegen.py -> build/lib.macosx-10.9-x86_64-3.8/numba/cuda
#   copying numba/cuda/libdevicedecl.py -> build/lib.macosx-10.9-x86_64-3.8/numba/cuda
#   copying numba/cuda/api_util.py -> build/lib.macosx-10.9-x86_64-3.8/numba/cuda
#   copying numba/cuda/decorators.py -> build/lib.macosx-10.9-x86_64-3.8/numba/cuda
#   creating build/lib.macosx-10.9-x86_64-3.8/numba/stencils
#   copying numba/stencils/stencil.py -> build/lib.macosx-10.9-x86_64-3.8/numba/stencils
#   copying numba/stencils/stencilparfor.py -> build/lib.macosx-10.9-x86_64-3.8/numba/stencils
#   copying numba/stencils/__init__.py -> build/lib.macosx-10.9-x86_64-3.8/numba/stencils
#   creating build/lib.macosx-10.9-x86_64-3.8/numba/pycc
#   copying numba/pycc/cc.py -> build/lib.macosx-10.9-x86_64-3.8/numba/pycc
#   copying numba/pycc/compiler.py -> build/lib.macosx-10.9-x86_64-3.8/numba/pycc
#   copying numba/pycc/llvm_types.py -> build/lib.macosx-10.9-x86_64-3.8/numba/pycc
#   copying numba/pycc/__init__.py -> build/lib.macosx-10.9-x86_64-3.8/numba/pycc
#   copying numba/pycc/platform.py -> build/lib.macosx-10.9-x86_64-3.8/numba/pycc
#   copying numba/pycc/decorators.py -> build/lib.macosx-10.9-x86_64-3.8/numba/pycc
#   creating build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_support.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_map_filter_reduce.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_llvm_version_check.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_builtins.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_jitmethod.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_inlining.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_array_manipulation.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_dictobject.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_dummyarray.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_linalg.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_function_type.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/parfors_cache_usecases.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_threadsafety.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/cfunc_cache_usecases.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/gdb_support.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/overload_usecases.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/enum_usecases.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_debuginfo.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_func_lifetime.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_typeinfer.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_unicode.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_asnumbatype.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_return_values.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_parallel_backend.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_nrt.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_typeguard.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_vectorization.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_warnings.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_typenames.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_moved_modules.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/orphaned_semaphore_usecase.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_mangling.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_npdatetime.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_fancy_indexing.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_practical_lowering_issues.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/support.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_print.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_parfors_passes.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_ssa.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_debug.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_interproc.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_target_extension.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_typeconv.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_np_functions.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_typedobjectutils.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_tracing.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_ir_inlining.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/usecases.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_vectorization_type_inference.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/matmul_usecase.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_make_function_to_jit_function.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/complex_usecases.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_array_exprs.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_python_int.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_jitclasses.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_polynomial.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_wrapper.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_obj_lifetime.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_intwidth.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/cloudpickle_main_class.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_llvm_pass_timings.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_extending.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_remove_dead.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/serialize_usecases.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_funcdesc.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_unsafe_intrinsics.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_literal_dispatch.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_listobject.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_gil.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_array_constants.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/cffi_usecases.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_numbers.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_slices.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_mandelbrot.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_numpy_support.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/compile_with_pycc.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_ir.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_deprecations.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_looplifting.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_storeslice.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/recursion_usecases.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_init_utils.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_generators.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/dummy_module.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_struct_ref.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_recursion.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_operators.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_dictimpl.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_analysis.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_maxmin.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_exceptions.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/__init__.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_comprehension.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/ctypes_usecases.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_listimpl.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_locals.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_dicts.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_optional.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_mathlib.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_ir_utils.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_numberctor.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_globals.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_typingerror.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_object_mode.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_copy_propagate.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_ctypes.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_typeof.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_usecases.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_auto_constants.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_cffi.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_try_except.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_sort.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/parfors_max_label_error.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_cfunc.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_conversion.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_indexing.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_pycc.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_byteflow.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/annotation_usecases.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_retargeting.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_unicode_names.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_extended_arg.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_alignment.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_ndarray_subclasses.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_multi3.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_extending_types.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_import.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_overlap.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_array_attr.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/error_usecases.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_array_methods.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_conditions_as_predicates.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_func_interface.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_gdb_dwarf.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_event.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_enums.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_profiler.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_numpyadapt.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_mixed_tuple_unroller.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_stencils.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_annotations.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/cache_usecases.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_sysinfo.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_dataflow.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_tuples.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_svml.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_flow_control.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_array_iterators.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_buffer_protocol.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/inlining_usecases.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_casting.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_lists.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_blackscholes.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_array_analysis.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_config.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_serialize.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_typedlist.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_boundscheck.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_heapq.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_iteration.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_fastmath.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_numconv.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/threading_backend_usecases.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_runtests.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_errormodels.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_caching.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_recarray_usecases.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_target_overloadselector.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_compile_cache.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_gdb_bindings.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_array_reductions.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_dyn_func.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_refop_pruning.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_unpack_sequence.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_cgutils.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_api.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_compiler_lock.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_complex.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_jit_module.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_hashing.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_itanium_mangler.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_parfors_caching.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_sys_stdin_assignment.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_datamodel.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_closure.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_dispatcher.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_ufuncs.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/pdlike_usecase.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_range.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_cli.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_unicode_array.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_compiler_flags.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_num_threads.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_nrt_refct.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_nested_calls.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_chained_assign.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_withlifting.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_errorhandling.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_parfors.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_entrypoints.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_pipeline.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_sets.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_help.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_dyn_array.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_objects.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_record_dtype.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_types.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_codegen.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_random.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_array_return.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   copying numba/tests/test_nan.py -> build/lib.macosx-10.9-x86_64-3.8/numba/tests
#   creating build/lib.macosx-10.9-x86_64-3.8/numba/testing
#   copying numba/testing/__init__.py -> build/lib.macosx-10.9-x86_64-3.8/numba/testing
#   copying numba/testing/loader.py -> build/lib.macosx-10.9-x86_64-3.8/numba/testing
#   copying numba/testing/_runtests.py -> build/lib.macosx-10.9-x86_64-3.8/numba/testing
#   copying numba/testing/notebook.py -> build/lib.macosx-10.9-x86_64-3.8/numba/testing
#   copying numba/testing/main.py -> build/lib.macosx-10.9-x86_64-3.8/numba/testing
#   copying numba/testing/__main__.py -> build/lib.macosx-10.9-x86_64-3.8/numba/testing
#   creating build/lib.macosx-10.9-x86_64-3.8/numba/cpython
#   copying numba/cpython/setobj.py -> build/lib.macosx-10.9-x86_64-3.8/numba/cpython
#   copying numba/cpython/printimpl.py -> build/lib.macosx-10.9-x86_64-3.8/numba/cpython
#   copying numba/cpython/cmathimpl.py -> build/lib.macosx-10.9-x86_64-3.8/numba/cpython
#   copying numba/cpython/tupleobj.py -> build/lib.macosx-10.9-x86_64-3.8/numba/cpython
#   copying numba/cpython/mathimpl.py -> build/lib.macosx-10.9-x86_64-3.8/numba/cpython
#   copying numba/cpython/unicode.py -> build/lib.macosx-10.9-x86_64-3.8/numba/cpython
#   copying numba/cpython/heapq.py -> build/lib.macosx-10.9-x86_64-3.8/numba/cpython
#   copying numba/cpython/builtins.py -> build/lib.macosx-10.9-x86_64-3.8/numba/cpython
#   copying numba/cpython/randomimpl.py -> build/lib.macosx-10.9-x86_64-3.8/numba/cpython
#   copying numba/cpython/__init__.py -> build/lib.macosx-10.9-x86_64-3.8/numba/cpython
#   copying numba/cpython/slicing.py -> build/lib.macosx-10.9-x86_64-3.8/numba/cpython
#   copying numba/cpython/numbers.py -> build/lib.macosx-10.9-x86_64-3.8/numba/cpython
#   copying numba/cpython/listobj.py -> build/lib.macosx-10.9-x86_64-3.8/numba/cpython
#   copying numba/cpython/charseq.py -> build/lib.macosx-10.9-x86_64-3.8/numba/cpython
#   copying numba/cpython/rangeobj.py -> build/lib.macosx-10.9-x86_64-3.8/numba/cpython
#   copying numba/cpython/unicode_support.py -> build/lib.macosx-10.9-x86_64-3.8/numba/cpython
#   copying numba/cpython/iterators.py -> build/lib.macosx-10.9-x86_64-3.8/numba/cpython
#   copying numba/cpython/enumimpl.py -> build/lib.macosx-10.9-x86_64-3.8/numba/cpython
#   copying numba/cpython/hashing.py -> build/lib.macosx-10.9-x86_64-3.8/numba/cpython
#   creating build/lib.macosx-10.9-x86_64-3.8/numba/parfors
#   copying numba/parfors/parfor_lowering_utils.py -> build/lib.macosx-10.9-x86_64-3.8/numba/parfors
#   copying numba/parfors/parfor_lowering.py -> build/lib.macosx-10.9-x86_64-3.8/numba/parfors
#   copying numba/parfors/parfor.py -> build/lib.macosx-10.9-x86_64-3.8/numba/parfors
#   copying numba/parfors/__init__.py -> build/lib.macosx-10.9-x86_64-3.8/numba/parfors
#   copying numba/parfors/array_analysis.py -> build/lib.macosx-10.9-x86_64-3.8/numba/parfors
#   creating build/lib.macosx-10.9-x86_64-3.8/numba/cext
#   copying numba/cext/__init__.py -> build/lib.macosx-10.9-x86_64-3.8/numba/cext
#   creating build/lib.macosx-10.9-x86_64-3.8/numba/scripts
#   copying numba/scripts/generate_lower_listing.py -> build/lib.macosx-10.9-x86_64-3.8/numba/scripts
#   copying numba/scripts/__init__.py -> build/lib.macosx-10.9-x86_64-3.8/numba/scripts
#   creating build/lib.macosx-10.9-x86_64-3.8/numba/typed
#   copying numba/typed/typedlist.py -> build/lib.macosx-10.9-x86_64-3.8/numba/typed
#   copying numba/typed/dictimpl.py -> build/lib.macosx-10.9-x86_64-3.8/numba/typed
#   copying numba/typed/__init__.py -> build/lib.macosx-10.9-x86_64-3.8/numba/typed
#   copying numba/typed/listobject.py -> build/lib.macosx-10.9-x86_64-3.8/numba/typed
#   copying numba/typed/dictobject.py -> build/lib.macosx-10.9-x86_64-3.8/numba/typed
#   copying numba/typed/typedobjectutils.py -> build/lib.macosx-10.9-x86_64-3.8/numba/typed
#   copying numba/typed/typeddict.py -> build/lib.macosx-10.9-x86_64-3.8/numba/typed
#   creating build/lib.macosx-10.9-x86_64-3.8/numba/np
#   copying numba/np/ufunc_db.py -> build/lib.macosx-10.9-x86_64-3.8/numba/np
#   copying numba/np/npyimpl.py -> build/lib.macosx-10.9-x86_64-3.8/numba/np
#   copying numba/np/numpy_support.py -> build/lib.macosx-10.9-x86_64-3.8/numba/np
#   copying numba/np/__init__.py -> build/lib.macosx-10.9-x86_64-3.8/numba/np
#   copying numba/np/extensions.py -> build/lib.macosx-10.9-x86_64-3.8/numba/np
#   copying numba/np/arraymath.py -> build/lib.macosx-10.9-x86_64-3.8/numba/np
#   copying numba/np/linalg.py -> build/lib.macosx-10.9-x86_64-3.8/numba/np
#   copying numba/np/npdatetime_helpers.py -> build/lib.macosx-10.9-x86_64-3.8/numba/np
#   copying numba/np/npyfuncs.py -> build/lib.macosx-10.9-x86_64-3.8/numba/np
#   copying numba/np/arrayobj.py -> build/lib.macosx-10.9-x86_64-3.8/numba/np
#   copying numba/np/polynomial.py -> build/lib.macosx-10.9-x86_64-3.8/numba/np
#   copying numba/np/npdatetime.py -> build/lib.macosx-10.9-x86_64-3.8/numba/np
#   creating build/lib.macosx-10.9-x86_64-3.8/numba/misc/help
#   copying numba/misc/help/inspector.py -> build/lib.macosx-10.9-x86_64-3.8/numba/misc/help
#   copying numba/misc/help/__init__.py -> build/lib.macosx-10.9-x86_64-3.8/numba/misc/help
#   creating build/lib.macosx-10.9-x86_64-3.8/numba/experimental/jitclass
#   copying numba/experimental/jitclass/__init__.py -> build/lib.macosx-10.9-x86_64-3.8/numba/experimental/jitclass
#   copying numba/experimental/jitclass/boxing.py -> build/lib.macosx-10.9-x86_64-3.8/numba/experimental/jitclass
#   copying numba/experimental/jitclass/base.py -> build/lib.macosx-10.9-x86_64-3.8/numba/experimental/jitclass
#   copying numba/experimental/jitclass/decorators.py -> build/lib.macosx-10.9-x86_64-3.8/numba/experimental/jitclass
#   creating build/lib.macosx-10.9-x86_64-3.8/numba/core/typeconv
#   copying numba/core/typeconv/typeconv.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core/typeconv
#   copying numba/core/typeconv/__init__.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core/typeconv
#   copying numba/core/typeconv/rules.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core/typeconv
#   copying numba/core/typeconv/castgraph.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core/typeconv
#   creating build/lib.macosx-10.9-x86_64-3.8/numba/core/rewrites
#   copying numba/core/rewrites/ir_print.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core/rewrites
#   copying numba/core/rewrites/registry.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core/rewrites
#   copying numba/core/rewrites/static_raise.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core/rewrites
#   copying numba/core/rewrites/__init__.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core/rewrites
#   copying numba/core/rewrites/static_getitem.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core/rewrites
#   copying numba/core/rewrites/static_binop.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core/rewrites
#   creating build/lib.macosx-10.9-x86_64-3.8/numba/core/types
#   copying numba/core/types/abstract.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core/types
#   copying numba/core/types/functions.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core/types
#   copying numba/core/types/misc.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core/types
#   copying numba/core/types/function_type.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core/types
#   copying numba/core/types/containers.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core/types
#   copying numba/core/types/npytypes.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core/types
#   copying numba/core/types/__init__.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core/types
#   copying numba/core/types/common.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core/types
#   copying numba/core/types/iterators.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core/types
#   copying numba/core/types/scalars.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core/types
#   creating build/lib.macosx-10.9-x86_64-3.8/numba/core/runtime
#   copying numba/core/runtime/nrt.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core/runtime
#   copying numba/core/runtime/__init__.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core/runtime
#   copying numba/core/runtime/nrtdynmod.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core/runtime
#   copying numba/core/runtime/nrtopt.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core/runtime
#   copying numba/core/runtime/context.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core/runtime
#   creating build/lib.macosx-10.9-x86_64-3.8/numba/core/typing
#   copying numba/core/typing/cmathdecl.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core/typing
#   copying numba/core/typing/bufproto.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core/typing
#   copying numba/core/typing/mathdecl.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core/typing
#   copying numba/core/typing/dictdecl.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core/typing
#   copying numba/core/typing/listdecl.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core/typing
#   copying numba/core/typing/builtins.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core/typing
#   copying numba/core/typing/randomdecl.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core/typing
#   copying numba/core/typing/asnumbatype.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core/typing
#   copying numba/core/typing/__init__.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core/typing
#   copying numba/core/typing/setdecl.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core/typing
#   copying numba/core/typing/npydecl.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core/typing
#   copying numba/core/typing/templates.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core/typing
#   copying numba/core/typing/arraydecl.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core/typing
#   copying numba/core/typing/context.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core/typing
#   copying numba/core/typing/collections.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core/typing
#   copying numba/core/typing/ctypes_utils.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core/typing
#   copying numba/core/typing/enumdecl.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core/typing
#   copying numba/core/typing/cffi_utils.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core/typing
#   copying numba/core/typing/typeof.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core/typing
#   copying numba/core/typing/npdatetime.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core/typing
#   creating build/lib.macosx-10.9-x86_64-3.8/numba/core/annotations
#   copying numba/core/annotations/type_annotations.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core/annotations
#   copying numba/core/annotations/__init__.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core/annotations
#   copying numba/core/annotations/pretty_annotate.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core/annotations
#   creating build/lib.macosx-10.9-x86_64-3.8/numba/core/unsafe
#   copying numba/core/unsafe/refcount.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core/unsafe
#   copying numba/core/unsafe/eh.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core/unsafe
#   copying numba/core/unsafe/nrt.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core/unsafe
#   copying numba/core/unsafe/__init__.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core/unsafe
#   copying numba/core/unsafe/bytes.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core/unsafe
#   creating build/lib.macosx-10.9-x86_64-3.8/numba/core/datamodel
#   copying numba/core/datamodel/models.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core/datamodel
#   copying numba/core/datamodel/registry.py -> build/lib.macosx-10.9-x86_64-3.8/numba/core/datamodel
# ...
#   copying numba/mathnames.h -> build/lib.macosx-10.9-x86_64-3.8/numba
#   copying numba/_numba_common.h -> build/lib.macosx-10.9-x86_64-3.8/numba
#   copying numba/_pymodule.h -> build/lib.macosx-10.9-x86_64-3.8/numba
#   copying numba/_unicodetype_db.h -> build/lib.macosx-10.9-x86_64-3.8/numba
#   copying numba/misc/cmdlang.gdb -> build/lib.macosx-10.9-x86_64-3.8/numba/misc
#   copying numba/pycc/modulemixin.c -> build/lib.macosx-10.9-x86_64-3.8/numba/pycc
#   copying numba/cext/listobject.c -> build/lib.macosx-10.9-x86_64-3.8/numba/cext
#   copying numba/cext/utils.c -> build/lib.macosx-10.9-x86_64-3.8/numba/cext
#   copying numba/cext/dictobject.c -> build/lib.macosx-10.9-x86_64-3.8/numba/cext
#   copying numba/cext/dictobject.h -> build/lib.macosx-10.9-x86_64-3.8/numba/cext
#   copying numba/cext/cext.h -> build/lib.macosx-10.9-x86_64-3.8/numba/cext
#   copying numba/cext/listobject.h -> build/lib.macosx-10.9-x86_64-3.8/numba/cext
#   copying numba/typed/py.typed -> build/lib.macosx-10.9-x86_64-3.8/numba/typed
#   copying numba/core/runtime/_nrt_python.c -> build/lib.macosx-10.9-x86_64-3.8/numba/core/runtime
#   copying numba/core/runtime/_nrt_pythonmod.c -> build/lib.macosx-10.9-x86_64-3.8/numba/core/runtime
#   copying numba/core/runtime/nrt.c -> build/lib.macosx-10.9-x86_64-3.8/numba/core/runtime
#   copying numba/core/runtime/nrt.h -> build/lib.macosx-10.9-x86_64-3.8/numba/core/runtime
#   copying numba/core/runtime/nrt_external.h -> build/lib.macosx-10.9-x86_64-3.8/numba/core/runtime
#   copying numba/core/annotations/template.html -> build/lib.macosx-10.9-x86_64-3.8/numba/core/annotations
#   copying numba/cuda/tests/cudadrv/data/jitlink.ptx -> build/lib.macosx-10.9-x86_64-3.8/numba/cuda/tests/cudadrv/data
#   running build_ext
#   building 'numba._dynfunc' extension
#   Warning: Can't read registry to find the necessary compiler setting
#   Make sure that Python modules winreg, win32api or win32con are installed.
#   C compiler: gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -I/Users/danielaquijano/opt/anaconda3/envs/NewPython33122/include -arch x86_64 -I/Users/danielaquijano/opt/anaconda3/envs/NewPython33122/include -arch x86_64
#
#   creating build/temp.macosx-10.9-x86_64-3.8
#   creating build/temp.macosx-10.9-x86_64-3.8/numba
#   compile options: '-I/Users/danielaquijano/opt/anaconda3/envs/NewPython33122/include/python3.8 -c'
#   gcc: numba/_dynfuncmod.c
#   In file included from numba/_dynfuncmod.c:1:
#   numba/_dynfunc.c:143:5: warning: 'tp_print' is deprecated [-Wdeprecated-declarations]
#       0,                         /* tp_print */
#       ^
#   /Users/danielaquijano/opt/anaconda3/envs/NewPython33122/include/python3.8/cpython/object.h:260:5: note: 'tp_print' has been explicitly marked deprecated here
#       Py_DEPRECATED(3.8) int (*tp_print)(PyObject *, FILE *, int);
#       ^
#   /Users/danielaquijano/opt/anaconda3/envs/NewPython33122/include/python3.8/pyport.h:515:54: note: expanded from macro 'Py_DEPRECATED'
#   #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                        ^
#   In file included from numba/_dynfuncmod.c:1:
#   numba/_dynfunc.c:253:5: warning: 'tp_print' is deprecated [-Wdeprecated-declarations]
#       0,                         /* tp_print */
#       ^
#   /Users/danielaquijano/opt/anaconda3/envs/NewPython33122/include/python3.8/cpython/object.h:260:5: note: 'tp_print' has been explicitly marked deprecated here
#       Py_DEPRECATED(3.8) int (*tp_print)(PyObject *, FILE *, int);
#       ^
#   /Users/danielaquijano/opt/anaconda3/envs/NewPython33122/include/python3.8/pyport.h:515:54: note: expanded from macro 'Py_DEPRECATED'
#   #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                        ^
#   In file included from numba/_dynfuncmod.c:1:
#   numba/_dynfunc.c:470:5: warning: 'tp_print' is deprecated [-Wdeprecated-declarations]
#       0,                         /* tp_print */
#       ^
#   /Users/danielaquijano/opt/anaconda3/envs/NewPython33122/include/python3.8/cpython/object.h:260:5: note: 'tp_print' has been explicitly marked deprecated here
#       Py_DEPRECATED(3.8) int (*tp_print)(PyObject *, FILE *, int);
#       ^
#   /Users/danielaquijano/opt/anaconda3/envs/NewPython33122/include/python3.8/pyport.h:515:54: note: expanded from macro 'Py_DEPRECATED'
#   #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                        ^
#   3 warnings generated.
#   gcc -bundle -undefined dynamic_lookup -L/Users/danielaquijano/opt/anaconda3/envs/NewPython33122/lib -arch x86_64 -L/Users/danielaquijano/opt/anaconda3/envs/NewPython33122/lib -arch x86_64 -arch x86_64 build/temp.macosx-10.9-x86_64-3.8/numba/_dynfuncmod.o -o build/lib.macosx-10.9-x86_64-3.8/numba/_dynfunc.cpython-38-darwin.so
#   building 'numba._dispatcher' extension
#   C compiler: gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -I/Users/danielaquijano/opt/anaconda3/envs/NewPython33122/include -arch x86_64 -I/Users/danielaquijano/opt/anaconda3/envs/NewPython33122/include -arch x86_64
#
#   creating build/temp.macosx-10.9-x86_64-3.8/numba/core
#   creating build/temp.macosx-10.9-x86_64-3.8/numba/core/typeconv
#   compile options: '-I/Users/danielaquijano/opt/anaconda3/envs/NewPython33122/lib/python3.8/site-packages/numpy/core/include -I/Users/danielaquijano/opt/anaconda3/envs/NewPython33122/include/python3.8 -c'
#   gcc: numba/_dispatcher.cppgcc: numba/_typeof.c
#   gcc: numba/_hashtable.c
#
#   gcc: numba/core/typeconv/typeconv.cpp
#   numba/_dispatcher.cpp:1104:37: warning: offset of on non-POD type 'Dispatcher' [-Winvalid-offsetof]
#       {(char*)"_can_compile", T_BOOL, offsetof(Dispatcher, can_compile), 0, NULL },
#                                       ^                    ~~~~~~~~~~~
#   /Library/Developer/CommandLineTools/usr/lib/clang/10.0.0/include/stddef.h:120:24: note: expanded from macro 'offsetof'
#   #define offsetof(t, d) __builtin_offsetof(t, d)
#                          ^                     ~
#   numba/_dispatcher.cpp:1163:5: warning: 'tp_print' is deprecated [-Wdeprecated-declarations]
#       0,                                           /* tp_print */
#       ^
#   /Users/danielaquijano/opt/anaconda3/envs/NewPython33122/include/python3.8/cpython/object.h:260:5: note: 'tp_print' has been explicitly marked deprecated here
#       Py_DEPRECATED(3.8) int (*tp_print)(PyObject *, FILE *, int);
#       ^
#   /Users/danielaquijano/opt/anaconda3/envs/NewPython33122/include/python3.8/pyport.h:515:54: note: expanded from macro 'Py_DEPRECATED'
#   #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                        ^
#   2 warnings generated.
#   g++ -bundle -undefined dynamic_lookup -L/Users/danielaquijano/opt/anaconda3/envs/NewPython33122/lib -arch x86_64 -L/Users/danielaquijano/opt/anaconda3/envs/NewPython33122/lib -arch x86_64 -arch x86_64 build/temp.macosx-10.9-x86_64-3.8/numba/_dispatcher.o build/temp.macosx-10.9-x86_64-3.8/numba/_typeof.o build/temp.macosx-10.9-x86_64-3.8/numba/_hashtable.o build/temp.macosx-10.9-x86_64-3.8/numba/core/typeconv/typeconv.o -L/Users/danielaquijano/opt/anaconda3/envs/NewPython33122/lib/python3.8/site-packages/numpy/core/lib -lnpymath -o build/lib.macosx-10.9-x86_64-3.8/numba/_dispatcher.cpython-38-darwin.so
#   building 'numba._helperlib' extension
#   C compiler: gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -I/Users/danielaquijano/opt/anaconda3/envs/NewPython33122/include -arch x86_64 -I/Users/danielaquijano/opt/anaconda3/envs/NewPython33122/include -arch x86_64
#
#   creating build/temp.macosx-10.9-x86_64-3.8/numba/cext
#   compile options: '-I/Users/danielaquijano/opt/anaconda3/envs/NewPython33122/lib/python3.8/site-packages/numpy/core/include -I/Users/danielaquijano/opt/anaconda3/envs/NewPython33122/include/python3.8 -c'
#   gcc: numba/cext/utils.cgcc: numba/_helpermod.cgcc: numba/cext/dictobject.c
#
#   gcc: numba/cext/listobject.c
#
#   gcc -bundle -undefined dynamic_lookup -L/Users/danielaquijano/opt/anaconda3/envs/NewPython33122/lib -arch x86_64 -L/Users/danielaquijano/opt/anaconda3/envs/NewPython33122/lib -arch x86_64 -arch x86_64 build/temp.macosx-10.9-x86_64-3.8/numba/_helpermod.o build/temp.macosx-10.9-x86_64-3.8/numba/cext/utils.o build/temp.macosx-10.9-x86_64-3.8/numba/cext/dictobject.o build/temp.macosx-10.9-x86_64-3.8/numba/cext/listobject.o -L/Users/danielaquijano/opt/anaconda3/envs/NewPython33122/lib/python3.8/site-packages/numpy/core/lib -lnpymath -o build/lib.macosx-10.9-x86_64-3.8/numba/_helperlib.cpython-38-darwin.so -headerpad_max_install_names
#   ld: in /Users/danielaquijano/opt/anaconda3/envs/NewPython33122/lib/python3.8/site-packages/numpy/core/lib/libnpymath.a(npy_math.o), could not parse object file /Users/danielaquijano/opt/anaconda3/envs/NewPython33122/lib/python3.8/site-packages/numpy/core/lib/libnpymath.a(npy_math.o): 'Unknown attribute kind (61) (Producer: 'LLVM10.0.0' Reader: 'LLVM APPLE_1_1000.10.44.4_0')', using libLTO version 'LLVM version 10.0.0, (clang-1000.10.44.4)' for architecture x86_64
#   clang: error: linker command failed with exit code 1 (use -v to see invocation)
#   error: Command "gcc -bundle -undefined dynamic_lookup -L/Users/danielaquijano/opt/anaconda3/envs/NewPython33122/lib -arch x86_64 -L/Users/danielaquijano/opt/anaconda3/envs/NewPython33122/lib -arch x86_64 -arch x86_64 build/temp.macosx-10.9-x86_64-3.8/numba/_helpermod.o build/temp.macosx-10.9-x86_64-3.8/numba/cext/utils.o build/temp.macosx-10.9-x86_64-3.8/numba/cext/dictobject.o build/temp.macosx-10.9-x86_64-3.8/numba/cext/listobject.o -L/Users/danielaquijano/opt/anaconda3/envs/NewPython33122/lib/python3.8/site-packages/numpy/core/lib -lnpymath -o build/lib.macosx-10.9-x86_64-3.8/numba/_helperlib.cpython-38-darwin.so -headerpad_max_install_names" failed with exit status 1
#   ----------------------------------------
#   ERROR: Failed building wheel for numba
#   Running setup.py clean for numba
# Failed to build numba
# Installing collected packages: threadpoolctl, scipy, llvmlite, joblib, scikit-learn, pillow, numba, kiwisolver, fonttools, cycler, tqdm, stdlib-list, pynndescent, patsy, natsort, matplotlib, h5py, umap-learn, tables, statsmodels, sinfo, seaborn, networkx, anndata, scanpy
#     Running setup.py install for numba ... error
#     ERROR: Command errored out with exit status 1:
#      command: /Users/danielaquijano/opt/anaconda3/envs/NewPython33122/bin/python -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/kz/671nytjx6wbb6qvvfpv7jwt00000gn/T/pip-install-zdjyhqrq/numba_f105f788a65940c9b7a7207648255752/setup.py'"'"'; __file__='"'"'/private/var/folders/kz/671nytjx6wbb6qvvfpv7jwt00000gn/T/pip-install-zdjyhqrq/numba_f105f788a65940c9b7a7207648255752/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record /private/var/folders/kz/671nytjx6wbb6qvvfpv7jwt00000gn/T/pip-record-javqoukz/install-record.txt --single-version-externally-managed --compile --install-headers /Users/danielaquijano/opt/anaconda3/envs/NewPython33122/include/python3.8/numba
#          cwd: /private/var/folders/kz/671nytjx6wbb6qvvfpv7jwt00000gn/T/pip-install-zdjyhqrq/numba_f105f788a65940c9b7a7207648255752/
#     Complete output (24 lines):
#     TBB not found
#     Using OpenMP from: /Users/danielaquijano/opt/anaconda3
#     running install
#     running build
#     got version from file /private/var/folders/kz/671nytjx6wbb6qvvfpv7jwt00000gn/T/pip-install-zdjyhqrq/numba_f105f788a65940c9b7a7207648255752/numba/_version.py {'version': '0.55.1', 'full': '76720bf88350c70b99ab3d4272d01bd9f14eeace'}
#     running build_py
#     running build_ext
#     building 'numba._helperlib' extension
#     Warning: Can't read registry to find the necessary compiler setting
#     Make sure that Python modules winreg, win32api or win32con are installed.
#     C compiler: gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -I/Users/danielaquijano/opt/anaconda3/envs/NewPython33122/include -arch x86_64 -I/Users/danielaquijano/opt/anaconda3/envs/NewPython33122/include -arch x86_64
#
#     creating build/temp.macosx-10.9-x86_64-3.8
#     creating build/temp.macosx-10.9-x86_64-3.8/numba
#     creating build/temp.macosx-10.9-x86_64-3.8/numba/cext
#     compile options: '-I/Users/danielaquijano/opt/anaconda3/envs/NewPython33122/lib/python3.8/site-packages/numpy/core/include -I/Users/danielaquijano/opt/anaconda3/envs/NewPython33122/include/python3.8 -c'
#     gcc: numba/_helpermod.cgcc: numba/cext/utils.c
#
#     gcc: numba/cext/dictobject.c
#     gcc: numba/cext/listobject.c
#     gcc -bundle -undefined dynamic_lookup -L/Users/danielaquijano/opt/anaconda3/envs/NewPython33122/lib -arch x86_64 -L/Users/danielaquijano/opt/anaconda3/envs/NewPython33122/lib -arch x86_64 -arch x86_64 build/temp.macosx-10.9-x86_64-3.8/numba/_helpermod.o build/temp.macosx-10.9-x86_64-3.8/numba/cext/utils.o build/temp.macosx-10.9-x86_64-3.8/numba/cext/dictobject.o build/temp.macosx-10.9-x86_64-3.8/numba/cext/listobject.o -L/Users/danielaquijano/opt/anaconda3/envs/NewPython33122/lib/python3.8/site-packages/numpy/core/lib -lnpymath -o build/lib.macosx-10.9-x86_64-3.8/numba/_helperlib.cpython-38-darwin.so -headerpad_max_install_names
#     ld: in /Users/danielaquijano/opt/anaconda3/envs/NewPython33122/lib/python3.8/site-packages/numpy/core/lib/libnpymath.a(npy_math.o), could not parse object file /Users/danielaquijano/opt/anaconda3/envs/NewPython33122/lib/python3.8/site-packages/numpy/core/lib/libnpymath.a(npy_math.o): 'Unknown attribute kind (61) (Producer: 'LLVM10.0.0' Reader: 'LLVM APPLE_1_1000.10.44.4_0')', using libLTO version 'LLVM version 10.0.0, (clang-1000.10.44.4)' for architecture x86_64
#     clang: error: linker command failed with exit code 1 (use -v to see invocation)
#     error: Command "gcc -bundle -undefined dynamic_lookup -L/Users/danielaquijano/opt/anaconda3/envs/NewPython33122/lib -arch x86_64 -L/Users/danielaquijano/opt/anaconda3/envs/NewPython33122/lib -arch x86_64 -arch x86_64 build/temp.macosx-10.9-x86_64-3.8/numba/_helpermod.o build/temp.macosx-10.9-x86_64-3.8/numba/cext/utils.o build/temp.macosx-10.9-x86_64-3.8/numba/cext/dictobject.o build/temp.macosx-10.9-x86_64-3.8/numba/cext/listobject.o -L/Users/danielaquijano/opt/anaconda3/envs/NewPython33122/lib/python3.8/site-packages/numpy/core/lib -lnpymath -o build/lib.macosx-10.9-x86_64-3.8/numba/_helperlib.cpython-38-darwin.so -headerpad_max_install_names" failed with exit status 1
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: /Users/danielaquijano/opt/anaconda3/envs/NewPython33122/bin/python -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/kz/671nytjx6wbb6qvvfpv7jwt00000gn/T/pip-install-zdjyhqrq/numba_f105f788a65940c9b7a7207648255752/setup.py'"'"'; __file__='"'"'/private/var/folders/kz/671nytjx6wbb6qvvfpv7jwt00000gn/T/pip-install-zdjyhqrq/numba_f105f788a65940c9b7a7207648255752/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record /private/var/folders/kz/671nytjx6wbb6qvvfpv7jwt00000gn/T/pip-record-javqoukz/install-record.txt --single-version-externally-managed --compile --install-headers /Users/danielaquijano/opt/anaconda3/envs/NewPython33122/include/python3.8/numba Check the logs for full command output.
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import scanpy as sc
import os

# %%
# !pip install leidenalg
# !pip install louvain
# Out:
# Collecting leidenalg
#   Downloading leidenalg-0.8.9-cp38-cp38-macosx_10_9_x86_64.whl (230 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 230.6/230.6 KB 618.6 kB/s eta 0:00:0000:0100:01
# Collecting igraph<0.10,>=0.9.0
#   Downloading igraph-0.9.9-cp38-cp38-macosx_10_9_x86_64.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 831.7 kB/s eta 0:00:0000:0100:01
# Collecting texttable>=1.6.2
#   Downloading texttable-1.6.4-py2.py3-none-any.whl (10 kB)
# Installing collected packages: texttable, igraph, leidenalg
# Successfully installed igraph-0.9.9 leidenalg-0.8.9 texttable-1.6.4
# Collecting louvain
#   Downloading louvain-0.7.1-cp38-cp38-macosx_10_9_x86_64.whl (210 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 210.4/210.4 KB 829.5 kB/s eta 0:00:0000:0100:01
# Requirement already satisfied: igraph>=0.9.5 in /Users/danielaquijano/opt/anaconda3/lib/python3.8/site-packages (from louvain) (0.9.9)
# Requirement already satisfied: texttable>=1.6.2 in /Users/danielaquijano/opt/anaconda3/lib/python3.8/site-packages (from igraph>=0.9.5->louvain) (1.6.4)
# Installing collected packages: louvain
# Successfully installed louvain-0.7.1

# %%
import leidenalg
import louvain

# %%
sc.settings.verbosity = 3             # verbosity: errors (0), warnings (1), info (2), hints (3)
sc.logging.print_header()
sc.settings.set_figure_params(dpi=80, facecolor='white')
# Out:
# scanpy==1.8.2 anndata==0.8.0 umap==0.5.2 numpy==1.19.5 scipy==1.5.4 pandas==1.4.1 scikit-learn==0.23.2 statsmodels==0.12.2 python-igraph==0.9.9 louvain==0.7.1 pynndescent==0.5.6

# %%
# !gunzip /Users/danielaquijano/Documents/GitHub/RNA-Seq-Workflows/source_files/lung.h5ad.gz

# %%
results_file = '/Users/danielaquijano/Documents/GitHub/RNA-Seq-Workflows/output_files/results_lung.h5ad'  # the file that will store the analysis results

# %%
annotation_data = sc.read('/Users/danielaquijano/Documents/GitHub/RNA-Seq-Workflows/source_files/lung.h5ad')

# %%
annotation_data.var_names_make_unique()

# %%
annotation_data

# %%
sc.pl.highest_expr_genes(annotation_data , n_top=20, )

# %%
sc.pp.filter_cells(annotation_data, min_genes=200)
sc.pp.filter_genes(annotation_data, min_cells=3)
# Out:
# /Users/danielaquijano/opt/anaconda3/lib/python3.8/site-packages/anndata/compat/__init__.py:263: FutureWarning: During AnnData slicing, found matrix at .uns['W_harmony'] that happens to be dimensioned at n_obs×n_obs (106792×106792).
#
# These matrices should now be stored in the .obsp attribute.
# This slicing behavior will be removed in anndata 0.8.
#   warn(
# filtered out 1528 genes that are detected in less than 3 cells

# %%
annotation_data.var['mt'] = annotation_data.var_names.str.startswith('MT-')  # annotate the group of mitochondrial genes as 'mt'
sc.pp.calculate_qc_metrics(annotation_data, qc_vars=['mt'], percent_top=None, log1p=False, inplace=True)

# %%
sc.pl.violin(annotation_data, ['n_genes_by_counts', 'total_counts', 'pct_counts_mt'],
             jitter=0.4, multi_panel=True)

# %%
sc.pl.scatter(annotation_data, x='total_counts', y='pct_counts_mt')
sc.pl.scatter(annotation_data, x='total_counts', y='n_genes_by_counts')

# %%
annotation_data = annotation_data[annotation_data.obs.n_genes_by_counts < 2500, :]
annotation_data = annotation_data[annotation_data.obs.pct_counts_mt < 5, :]
# Out:
# /Users/danielaquijano/opt/anaconda3/lib/python3.8/site-packages/anndata/compat/__init__.py:263: FutureWarning: During AnnData slicing, found matrix at .uns['W_harmony'] that happens to be dimensioned at n_obs×n_obs (106792×106792).
#
# These matrices should now be stored in the .obsp attribute.
# This slicing behavior will be removed in anndata 0.8.
#   warn(

# %%
sc.pp.normalize_total(annotation_data, target_sum=1e4)
# Out:
# /Users/danielaquijano/opt/anaconda3/lib/python3.8/site-packages/scanpy/preprocessing/_normalization.py:155: UserWarning: Revieved a view of an AnnData. Making a copy.
#   view_to_actual(adata)
# normalizing counts per cell
#     finished (0:00:02)

# %%
sc.pp.log1p(annotation_data)

# %%
sc.pp.highly_variable_genes(annotation_data, min_mean=0.0125, max_mean=3, min_disp=0.5)
# Out:
# extracting highly variable genes
#     finished (0:00:08)
# --> added
#     'highly_variable', boolean vector (adata.var)
#     'means', float vector (adata.var)
#     'dispersions', float vector (adata.var)
#     'dispersions_norm', float vector (adata.var)

# %%
sc.pl.highly_variable_genes(annotation_data)

# %%
annotation_data = annotation_data[:, annotation_data.var.highly_variable]

# %%
sc.pp.regress_out(annotation_data, ['total_counts', 'pct_counts_mt'])
# Out:
# regressing out ['total_counts', 'pct_counts_mt']
#     sparse input is densified and may lead to high memory use
# /Users/danielaquijano/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:7: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import (to_datetime, Int64Index, DatetimeIndex, Period,
# /Users/danielaquijano/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:7: FutureWarning: pandas.Float64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import (to_datetime, Int64Index, DatetimeIndex, Period,
#     finished (0:13:04)

# %%
sc.pp.scale(annotation_data, max_value=10)

# %% [markdown]
# # Principal component analysis

# %%
sc.tl.pca(annotation_data, svd_solver='arpack')
# Out:
# computing PCA
#     on highly variable genes
#     with n_comps=50
#     finished (0:02:18)

# %%
sc.pl.pca(annotation_data, color='CST3')

# %%
annotation_data.write(results_file)

# %%
annotation_data
# Out:
# AnnData object with n_obs × n_vars = 94780 × 5047
#     obs: 'n_genes', 'n_UMI', 'percent_mito', 'method', 'doublet', 'predicted_celltype', 'compartment', 'Cluster', 'SubCluster', 'Viral+', 'leiden_res_2', 'leiden_res_1.3', 'donor', 'disease', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt'
#     var: 'featureid', 'n_cells', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'Nuc-Cell_colors', 'SubCluster_colors', 'W_harmony', 'genome', 'harmony_knn_distances', 'harmony_knn_indices', 'manual_coarse_annotation_colors', 'method_colors', 'modality', 'neighbors', 'pca', 'predictions_colors', 'sample_colors', 'umap', 'log1p', 'hvg'
#     obsm: 'X_harmony', 'X_pca', 'X_umap', 'sig_background'
#     varm: 'PCs', 'de_res'
#     layers: 'counts', 'winsorized'

# %% [markdown]
# # Neighborhood Graph

# %%
sc.pp.neighbors(annotation_data, n_neighbors=10, n_pcs=40)
# Out:
# computing neighbors
#     using 'X_pca' with n_pcs = 40
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:58)

# %%
sc.tl.leiden(annotation_data)
# Out:
# running Leiden clustering
#     finished: found 38 clusters and added
#     'leiden', the cluster labels (adata.obs, categorical) (0:00:30)

# %%
sc.pl.umap(annotation_data, color=['leiden', 'CST3', 'NKG7'])
